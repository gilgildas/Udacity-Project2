# %% [markdown]
# # Insight from Weratedogs Dataset

# %% [markdown]
# We will examine some insights from <strong>Weratedogs</strong> page, after cleaning and combining three datasets using various charts such as pie,bar and count plots will. Weratdogs is a dog-rating Twitter account,it has over 8 millions followers and  it has over 2000 dogs'pictures.People rate dogs on the scale of one to ten but it vary from one to thirteen. We will analyze different variables such as favorite, retweet, and dog type.

# %% [markdown]
# ![dog1.jpg](attachment:dog1.jpg)

# %% [markdown]
# <strong>1) How many images are there in a tweet?</strong>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Tweets have one, two, three or four image. Most tweets only have one image, as evidenced by the graph above. Because the data for the images is unbalanced, we cannot draw the conclusion that the number of images can influence the rating of dogs. which indicates that tweets with the most likes typically contain just one image. Furthermore, the graph shows that tweets are least likely to have four images in a single tweet

# %% [markdown]
# <strong>2) What device do people use to tweet?</strong>

# %% [markdown]
# ![pie.png](attachment:pie.png)

# %% [markdown]
# According to the graph above, 94.27 percent of people tweet about rating dogs using iPhone, sometimes use vine, and they least use Tweetdeck to tweet about dogs.
# We will examine some insights from the master achieve dataset after cleaning and combining three datasets with various charts.

# %% [markdown]
# <strong>3) What kind of dogs appear in tweets?</strong>

# %% [markdown]
# ![type.png](attachment:type.png)

# %% [markdown]
# Most tweets only contain one image, as evidenced by the graph above. Because the data for the images is unbalanced, we cannot draw the conclusion that the number of images can influence the rating of dogs. which indicates that tweets with the most likes typically contain just one image. Furthermore, the graph shows that tweets are least likely to have four images in a single tweet

# %% [markdown]
# <strong>4) What's the correlation between favorites and retweets?</strong>

# %% [markdown]
# ![scatter.png](attachment:scatter.png)

# %% [markdown]
# The graph above shows a positive correlation between images with many likes and images with the most retweets, implying that mostly liked dogs have more retweets than dogs with few likes. There are also a few images with few likes but many retweets.

# %% [markdown]
# <strong>5) Is there a link between favorite tweets and the time they were tweeted?</strong>

# %% [markdown]
# ![time.png](attachment:time.png)

# %% [markdown]
# The graph above shows that most tweets with many likes are tweeted in the evening, whereas most tweets with few likes are tweeted in the morning, implying that the time you tweeted matters whether you get many or few likes.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The insignts shows thats favorites and retweets have positive correlation and The time play important role to get more likes. The iphone is the most device people use to tweet about dogs.

# %% [markdown]
# ### Limitation

# %% [markdown]
# We didn't perform statistical test to confirm the insights.
